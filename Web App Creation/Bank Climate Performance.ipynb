# %%
import pandas as pd
import numpy as np
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', -1)

# %%
climate = pd.read_excel('data/bank_climate.xlsx', header=1)

# %%
bank_lst = ['Wells Fargo', 'JPMorgan Chase', 'Fairway Independent Mortgage', 'Caliber Home Loans', 'U.S. Bank', 
           'Loan Depot', 'Bank of America']

# %%
climate_dict = {}
for bank in bank_lst: 
    val = climate[climate['Bank'].str.contains(bank)]['Total'].values
    climate_dict[bank] = val

# %%
climate[climate['Bank'].str.contains('JPMorgan Chase')]['Total'].values
# Out:
# array([2.68593448e+11])

# %%
climate_dict['Wells Fargo']  = 197913994353.87134

# %%
climate_dict
# Out:
# {'Wells Fargo': array([1.97913994e+11]),
#  'JPMorgan Chase': array([2.68593448e+11]),
#  'Fairway Independent Mortgage': array([], dtype=float64),
#  'Caliber Home Loans': array([], dtype=float64),
#  'U.S. Bank': array([], dtype=float64),
#  'Loan Depot': array([], dtype=float64),
#  'Bank of America': array([1.56924771e+11])}

# %%
climate
# Out:
#     Rank                        Bank          2016          2017  \
# 0    1.0              JPMorgan Chase  6.398598e+10  7.065434e+10
# 1    2.0                 Wells Fargo  3.450441e+10  5.493113e+10
# 2    3.0                        Citi  4.306561e+10  4.609018e+10
# 3    4.0             Bank of America  3.759267e+10  3.633119e+10
# 4    5.0                         RBC  3.034578e+10  3.826808e+10
# 5    6.0                        MUFG  2.564022e+10  2.705585e+10
# 6    7.0                    Barclays  3.107220e+10  3.073316e+10
# 7    8.0                          TD  2.032776e+10  2.907064e+10
# 8    9.0                      Mizuho  2.182636e+10  1.986136e+10
# 9   10.0                  Scotiabank  1.878630e+10  2.387578e+10
# 10  11.0              Morgan Stanley  2.444127e+10  2.477241e+10
# 11  12.0                        HSBC  1.781424e+10  2.231901e+10
# 12  13.0                 BNP Paribas  1.776213e+10  1.806923e+10
# ...

# %%
# sustainable finance commitments 
susfin = pd.read_excel('data/sustainable_finance_commitments.xlsx', header=1)

# %%
susfin.columns
susfin.iloc[2]['Detailed\ndescription of criteria\nand/or list of activities,\nthemes, and/or sectors']
# Out:
# 'The commitment is designated for developing clean energy, lower-carbon technologies, and projects that contribute to the delivery of the Paris Climate Agreement and the UN Sustainable Development Goals.'

# %%
susfin.head()
# Out:
#                Bank name Location of bank headquarters  \
# 0   JPMorgan Chase & Co.                           US
# 1      Wells Fargo & Co.                            US
# 2                   HSBC                            UK
# 3        Bank of America                            US
# 4  Crédit Agricole Group                        France
#
#    Total assets (billions, USD; S&P 2018)  Total assets (USD; S&P 2018)  \
# 0                                 2533.60                  2.533600e+12
# 1                                 1951.76                  1.951760e+12
# 2                                 2521.77                  2.521770e+12
# 3                                 2281.23                  2.281230e+12
# 4                                 2117.16                  2.117160e+12
#
#   Does the bank have a sustainable finance commitment?  Commitment in USD  \
# 0                                               Yes          200000000000
# ...
